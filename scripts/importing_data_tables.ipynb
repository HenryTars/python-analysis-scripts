# %%
import sqlite3
import pandas as pd
import os

# Folder containing your CSV files
csv_folder = './data_tables'
db_name = 'cbs.db'

# Connect to the SQLite database
conn = sqlite3.connect(db_name)
cursor = conn.cursor()

# Step 1: Create/Replace Tables from CSVs
for filename in os.listdir(csv_folder):
    if filename.endswith('.csv'):
        table_name = os.path.splitext(filename)[0]  # Use filename (no extension) as table name
        file_path = os.path.join(csv_folder, filename)

        print(f"\nProcessing: {filename} -> Table: {table_name}")

        try:
            df = pd.read_csv(file_path, encoding='latin1', encoding_errors='ignore')
        except Exception as e:
            print(f"❌ Failed to read '{filename}': {e}")
            continue

        try:
            df.to_sql(table_name, conn, if_exists='replace', index=False)
            print(f"✅ Table '{table_name}' created/replaced and populated.")
        except Exception as e:
            print(f"❌ Failed to insert data into '{table_name}': {e}")
            continue

# Step 2: Show first 5 rows of all tables in the DB
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
all_tables = cursor.fetchall()

for (table_name,) in all_tables:
    print(f"\n📄 First 5 rows of table: '{table_name}'")
    try:
        df_preview = pd.read_sql_query(f"SELECT * FROM {table_name} LIMIT 5;", conn)
        display(df_preview) if 'display' in globals() else print(df_preview)
    except Exception as e:
        print(f"❌ Failed to query '{table_name}': {e}")
# Out:
# Processing: CSTB_AMOUNT_TAG.csv -> Table: CSTB_AMOUNT_TAG
# ✅ Table 'CSTB_AMOUNT_TAG' created/replaced and populated.
#
# Processing: CSTM_PRODUCT.csv -> Table: CSTM_PRODUCT
# ✅ Table 'CSTM_PRODUCT' created/replaced and populated.
#
# Processing: GLTM_GLMASTER.csv -> Table: GLTM_GLMASTER
# ✅ Table 'GLTM_GLMASTER' created/replaced and populated.
#
# Processing: SMTB_MODULES.csv -> Table: SMTB_MODULES
# ✅ Table 'SMTB_MODULES' created/replaced and populated.
#
# Processing: STTM_ACCOUNT_CLASS.csv -> Table: STTM_ACCOUNT_CLASS
# ✅ Table 'STTM_ACCOUNT_CLASS' created/replaced and populated.
#
# Processing: STTM_BRANCH.csv -> Table: STTM_BRANCH
# ✅ Table 'STTM_BRANCH' created/replaced and populated.
#
# Processing: STTM_TRN_CODE.csv -> Table: STTM_TRN_CODE
# ✅ Table 'STTM_TRN_CODE' created/replaced and populated.
#
# 📄 First 5 rows of table: 'ACVWS_ALL_AC_ENTRIES_ACRJRNAL'
#    AC_BRANCH AC_CCY  AC_ENTRY_SR_NO         AC_NO AML_EXCEPTION AMOUNT_TAG  \
# 0         13    TZS       582314624  013000017366          None    TXN_AMT
# 1         13    TZS       582314629      LI200065          None    OFS_AMT
# 2          0    TZS       482153753      AS200060          None   CHG_AMT1
# 3          0    TZS       482153758      LI200001          None   CHG_AMT2
# 4          0    TZS       482153759      AS200060          None   CHG_AMT2
#
#       AUTH_ID AUTH_STAT BALANCE_UPD BANK_CODE  ... RELATED_ACCOUNT  \
# 0        None         U           U      None  ...            None
# 1        None         U           U      None  ...    012000094121
# 2  FLEXSWITCH         A           U      None  ...            None
# 3  FLEXSWITCH         A           U      None  ...    001000327878
# 4  FLEXSWITCH         A           U      None  ...            None
#
#    RELATED_CUSTOMER  RELATED_REFERENCE              STMT_DT TRN_CODE  \
# 0        13166814.0               None  10/10/2024 00:00:00      GEP
# 1        13166814.0               None  10/10/2024 00:00:00      GEP
# 2          289771.0               None  01/02/2024 00:00:00      128
# 3          289771.0               None  01/02/2024 00:00:00      LEV
# 4          289771.0               None  01/02/2024 00:00:00      LEV
#
#                 TRN_DT        TRN_REF_NO        TXN_INIT_DATE     USER_ID  \
# 0  10/10/2024 00:00:00  013GEPL242840001  10/10/2024 00:00:00      BM1944
# 1  10/10/2024 00:00:00  013GEPL242840001  10/10/2024 00:00:00      BM1944
# 2  01/02/2024 00:00:00  999VCWR2400200WN  01/02/2024 00:00:00  FLEXSWITCH
# 3  01/02/2024 00:00:00  999VCWR2400200WN  01/02/2024 00:00:00  FLEXSWITCH
# 4  01/02/2024 00:00:00  999VCWR2400200WN  01/02/2024 00:00:00  FLEXSWITCH
#
#               VALUE_DT
# 0  10/10/2024 00:00:00
# 1  10/10/2024 00:00:00
# 2  01/02/2024 00:00:00
# 3  01/02/2024 00:00:00
# 4  01/02/2024 00:00:00
#
# [5 rows x 50 columns]
#
# 📄 First 5 rows of table: 'CSTB_AMOUNT_TAG'
#   ACCT_ENTRY_DEFN_ALLOWED       AMOUNT_TAG AMOUNT_TAG_TYPE CHARGE_ALLOWED  \
# 0                       Y  BC_ACP_ADV_DADJ               I              N
# 1                       Y  BC_ACP_ADV_LIQ1               I              N
# 2                       Y  BC_ACP_ADV_LIQ2               I              N
# 3                       Y  BC_ACP_ADV_LIQ3               I              N
# 4                       Y  BC_ACP_ADV_LIQ4               I              N
#
#   COMMISSION_ALLOWED                             DESCRIPTION INTEREST_ALLOWED  \
# 0                  N  Acceptance Commission for Import Bills                N
# 1                  N  Acceptance Commission for Import Bills                N
# 2                  N  Acceptance Commission for Import Bills                N
# 3                  N  Acceptance Commission for Import Bills                N
# 4                  N  Acceptance Commission for Import Bills                N
#
#   ISSR_TAX_ALLOWED LANGUAGE_CODE LCY_AVG_EQL_REQD MODULE OFFSET_AMOUNT_TAG  \
# 0             None           ENG             None     BC              None
# 1             None           ENG             None     BC              None
# 2             None           ENG             None     BC              None
# 3             None           ENG             None     BC              None
# 4             None           ENG             None     BC              None
#
#   TAG_TO_BE_AVG_EQL_WITH TAX_ALLOWED TRACK_PAYABLE TRACK_RECEIVABLE  \
# 0                   None           Y             N                N
# 1                   None           Y             N                N
# 2                   None           Y             N                N
# 3                   None           Y             N                N
# 4                   None           Y             N                N
#
#   TRACK_RECEIVABLES TRAN_TAX_ALLOWED UNREALISED USER_DEFINED
# 0              None             None       None         None
# 1              None             None       None         None
# 2              None             None       None         None
# 3              None             None       None         None
# 4              None             None       None         None
#
# 📄 First 5 rows of table: 'CSTM_PRODUCT'
#   ASSET_CATEGORIES_LIST AUTH_STAT BRANCHES_LIST CATEGORIES_LIST  \
# 0                  None         A             D               D
# 1                  None         A             D               D
# 2                  None         A             A               D
# 3                  None         A             D               D
# 4                  None         A             D               D
#
#       CHECKER_DT_STAMP CHECKER_ID CURRENCIES_LIST GEN_MT103P  \
# 0  03/28/2025 13:34:43     WM2012               D       None
# 1  07/13/2023 21:25:23     NM1524               D          Y
# 2  11/21/2018 17:51:35     MS1171               D          N
# 3  07/16/2018 19:22:02     GM1465               D          Y
# 4  07/16/2018 13:06:49     MS1171               D          Y
#
#   INCLUDE_FOR_TDS_CALC INSTRUMENT_PRODUCT_ALLOW  ... PRODUCT_GROUP  \
# 0                    N                     None  ...        RETAIL
# 1                 None                     None  ...            FT
# 2                 None                     None  ...            FT
# 3                 None                     None  ...            FT
# 4                 None                     None  ...            FT
#
#                PRODUCT_REMARKS                       PRODUCT_SLOGAN  \
# 0                         None      CREDIT INTEREST ON CALL ACCOUNT
# 1    OUTGOING - CUST - FOREIGN   OUTGOING CUSTOMER TRANSFER FOREIGN
# 2              OUTGOING - BANK               OUTGOING BANK TRANSFER
# 3    FT OUTGOING - MULTICREDIT  FT MULTI CREDIT - CUSTOMER - OUTGOI
# 4  FT - OUTGOING WALKING CUST.   OUTGOING WALKING CUSTOMER TRANSFER
#
#     PRODUCT_START_DATE  PRODUCT_TYPE RATE_CODE_PREFERRED  RATE_TYPE_PREFERRED  \
# 0  01/01/2008 00:00:00             I                None                 None
# 1  08/01/2007 00:00:00          None                None             STANDARD
# 2  08/01/2007 00:00:00          None                None             STANDARD
# 3  08/01/2007 00:00:00          None                None             STANDARD
# 4  08/01/2007 00:00:00          None                None             STANDARD
#
#    RECORD_STAT RTH_CLASS WAREHOUSE_CODE
# 0            O      None           None
# 1            O      None           None
# 2            O      None           None
# 3            O      None           None
# 4            O      None           None
#
# [5 rows x 35 columns]
#
# 📄 First 5 rows of table: 'GLTM_GLMASTER'
#   AC_STMT_CYCLE  AC_STMT_DAY AC_STMT_REQUIRED AC_STMT_TYPE ADDRESS1 ADDRESS2  \
# 0          None            0                N            N     None     None
# 1          None            0                N            N     None     None
# 2          None            0                N            N     None     None
# 3          None            0                N            N     None     None
# 4          None            0                N            N     None     None
#
#   ADDRESS3 ADDRESS4 ALLOW_BACK_PERIOD_ENTRY AUTH_STAT  ... POSTING_RES  \
# 0     None     None                       Y         A  ...           Y
# 1     None     None                       Y         A  ...           Y
# 2     None     None                       Y         A  ...           Y
# 3     None     None                       Y         A  ...           Y
# 4     None     None                       Y         A  ...           Y
#
#   PREV_YR_ADJ_GL PROFIT_ACC  RECON RECORD_STAT REPOST_FCY_ENTRIES RES_CCY  \
# 0           None       None      D           O                  N    None
# 1           None       None      D           O                  N    None
# 2           None       None      D           O                  N    None
# 3           None       None      D           O                  N    None
# 4           None       None      D           O                  N    None
#
#   REVAL TYPE ULTI_PARENT
# 0     Y    6    CL125000
# 1     Y    6    CL125000
# 2     Y    6    CL125000
# 3     Y    6    CA130000
# 4     Y    6    CA130000
#
# [5 rows x 53 columns]
#
# 📄 First 5 rows of table: 'SMTB_MODULES'
#   AC_CLASS_APPLICABLE ARC_APPLICABLE AUTH_STAT CB_CLASS_APPLICABLE  \
# 0                None           None         A                None
# 1                None           None         A                None
# 2                None           None         A                None
# 3                None           None         A                None
# 4                   Y           None         A                   Y
#
#   CH_CLASS_APPLICABLE     CHECKER_DT_STAMP CHECKER_ID CR_CLASS_APPLICABLE  \
# 0                None  10/03/2005 00:00:00     SYSTEM                None
# 1                None  10/03/2005 00:00:00     SYSTEM                None
# 2                None  03/10/2005 00:00:00     SYSTEM                None
# 3                None  03/10/2005 00:00:00     SYSTEM                None
# 4                   Y  03/10/2005 00:00:00     SYSTEM                   N
#
#   DISC_ACCR_APPLICABLE FA_BATCH_ENABLED  ... MAKER_ID MOD_NO  \
# 0                 None             None  ...   SYSTEM      1
# 1                 None             None  ...   SYSTEM      1
# 2                 None                N  ...   SYSTEM      1
# 3                 None                N  ...   SYSTEM      1
# 4                 None                N  ...   SYSTEM      1
#
#            MODULE_DESC MODULE_ID ONCE_AUTH PURGE_AVAILABLE  RECORD_STAT  \
# 0  Gateway Maintenance        GW         Y               Y            O
# 1  User Defined Fields        UD         Y               Y            O
# 2           Accounting        AC         Y               Y            O
# 3      Auto End of Day        AE         Y               Y            O
# 4     Asset Management        AM         Y               Y            O
#
#   RH_CLASS_APPLICABLE TA_CLASS_APPLICABLE USER_DEFINED_MODULE
# 0                None                None                   N
# 1                None                None                   N
# 2                None                None                   N
# 3                None                None                   N
# 4                   Y                   Y                   N
#
# [5 rows x 25 columns]
#
# 📄 First 5 rows of table: 'STTM_ACCOUNT_CLASS'
#   AC_CLASS_TYPE AC_STAT_DE_POST ACC_STATISTICS ACC_STMT_CYCLE ACC_STMT_CYCLE2  \
# 0             S               Y              Y              S            None
# 1             S               Y              Y              S            None
# 2             N               Y              Y              M            None
# 3             S               Y              Y              M            None
# 4             S               Y              Y              M            None
#
#   ACC_STMT_CYCLE3 ACC_STMT_TYPE ACC_STMT_TYPE2 ACC_STMT_TYPE3  \
# 0            None             D              N              N
# 1            None             D              N              N
# 2            None             D              N              N
# 3            None             S              N              N
# 4            None             S              N              N
#
#   ACCCLS_AUTODEP_LIST  ... TRACK_ACCRUED_IC TRACK_RECEIVABLE TRN_CODE  \
# 0                None  ...                Y                Y     None
# 1                None  ...                Y                Y     None
# 2                None  ...                Y                N     None
# 3                None  ...                Y                Y     None
# 4                None  ...                Y                Y     None
#
#   TRN_REV_CODE  TRNOVER_LMT_CODE TRUSTAC_CASH_LIMIT TURNOVER_EVENT_CLASS_CODE  \
# 0         None              None                0.0                      None
# 1         None              None                0.0                      None
# 2         None              None                0.0                      None
# 3         None              None                0.0                      None
# 4         None              None                0.0                      None
#
#   TURNOVER_RTOH_CODE TXN_CODE_LIST VERIFY_FUNDS_FOR_DRINT
# 0               None             D                      Y
# 1               None             D                      Y
# 2               None             D                      N
# 3               None             D                      Y
# 4               None             D                      Y
#
# [5 rows x 212 columns]
#
# 📄 First 5 rows of table: 'STTM_BRANCH'
#   ALLOW_CORPORATE_ACCESS ALT_BRANCH_CODE ATM_SUSPENSE_GL AUTH_STAT AUTO_AUTH  \
# 0                      N            None        LI148015         A         Y
# 1                      N            None        LI148015         A         Y
# 2                      N            None        LI148015         A         Y
# 3                      N            None        LI148015         A         Y
# 4                      N            None        LI148015         A         Y
#
#    BACK_VALUE_DAYS BACK_VALUED_CHK_REQ BANK_CODE BBAN_BANK_CODE BBAN_BRN_CODE  \
# 0                0                   N       ABL           None          None
# 1                0                   N       ABL           None          None
# 2                0                   N       ABL           None          None
# 3                0                   N       ABL           None          None
# 4                0                   N       ABL           None          None
#
#    ... TELEX_ADDR TIME_LEVEL TRACK_PY_PNL_ADJUSTMENT TRANSACTION_CODE  \
# 0  ...       None          0                       N             None
# 1  ...       None          0                       N             None
# 2  ...       None          0                       N             None
# 3  ...       None          0                       N             None
# 4  ...       None          0                       N             None
#
#   TRANSFER_TYPE  UNCOLLECTED_FUNDS_BASIS USER_DEF_ALGO WALKIN_CUSTOMER  \
# 0             R                        U          None         7068416
# 1             R                        U          None         1033176
# 2             R                        U          None         7068416
# 3             R                        U          None         7068416
# 4             R                        U          None         1033176
#
#   WEEK_HOL1 WEEK_HOL2
# 0         1      None
# 1         1      None
# 2         1      None
# 3         1      None
# 4         1      None
#
# [5 rows x 131 columns]
#
# 📄 First 5 rows of table: 'STTM_TRN_CODE'
#   ACUMEN_TRN_CODE AML_MONITORING AUTH_STAT AVAIL_BAL_REQD  AVL_DAYS AVL_INFO  \
# 0               N              N         A              Y         0        I
# 1               N              N         A              Y         0        I
# 2               N              N         A              Y         0        I
# 3               N              N         A              Y         0        I
# 4               N              N         A              Y         0        I
#
#   BAL_UPDATE_THRU_PPC     CHECKER_DT_STAMP CHECKER_ID CHEQUE_MANDATORY  ...  \
# 0                   N  04/24/2025 11:42:09     FC1156                N  ...
# 1                   N  04/23/2025 15:49:51     TN2011                N  ...
# 2                   N  01/09/2025 14:52:04     AB1584                N  ...
# 3                   N  01/09/2025 14:38:10     AB1584                N  ...
# 4                   N  01/09/2025 14:22:39     AB1584                N  ...
#
#   NEW_VAL_DATE ONCE_AUTH PRODUCT_CAT RECORD_STAT SALARY_CREDIT STMT_DT_BASIS  \
# 0         None         Y        None           O             N             C
# 1         None         Y        None           O             N             C
# 2         None         Y        None           O             N             C
# 3         None         Y        None           O             N             C
# 4         None         Y        None           O             N             C
#
#   TRN_CODE                                 TRN_DESC TRN_SWIFT_CODE  \
# 0      022                          INTERNAL CREDIT            MSC
# 1      419         SERVICE FEE FOR CURRENT ACCOUNTS            MSC
# 2      W12         DIGITAL WHATSAPP UTILITY PAYMENT            TRF
# 3      W69          DIGITAL MOBILE MERCHANT PAYMENT            TRF
# 4      W20  DIGITAL WHATSAPP MINI STATEMENT CHARGES            MSC
#
#   TRNOVER_LMT_INCLUSION
# 0                     N
# 1                     N
# 2                     N
# 3                     N
# 4                     N
#
# [5 rows x 40 columns]

# %%
# Get the schema: list of all table creation statements
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table_name in tables:
    table_name = table_name[0]
    print(f"\n--- Schema for table: {table_name} ---")
    cursor.execute(f"SELECT sql FROM sqlite_master WHERE type='table' AND name='{table_name}';")
    schema = cursor.fetchone()[0]
    print(schema)
# Out:
# --- Schema for table: ACVWS_ALL_AC_ENTRIES_ACRJRNAL ---
# CREATE TABLE "ACVWS_ALL_AC_ENTRIES_ACRJRNAL" (
# "AC_BRANCH" INTEGER,
#   "AC_CCY" TEXT,
#   "AC_ENTRY_SR_NO" INTEGER,
#   "AC_NO" TEXT,
#   "AML_EXCEPTION" REAL,
#   "AMOUNT_TAG" TEXT,
#   "AUTH_ID" TEXT,
#   "AUTH_STAT" TEXT,
#   "BALANCE_UPD" TEXT,
#   "BANK_CODE" REAL,
#   "BATCH_NO" REAL,
#   "CATEGORY" INTEGER,
#   "CURR_NO" INTEGER,
#   "CUST_GL" TEXT,
#   "DLY_HIST" TEXT,
#   "DONT_SHOWIN_STMT" TEXT,
#   "DRCR_IND" TEXT,
#   "ENTRY_SEQ_NO" INTEGER,
#   "EVENT" TEXT,
#   "EVENT_SR_NO" INTEGER,
#   "EXCH_RATE" REAL,
#   "EXTERNAL_REF_NO" TEXT,
#   "FCY_AMOUNT" REAL,
#   "FINANCIAL_CYCLE" TEXT,
#   "GLMIS_UPDATE_FLAG" REAL,
#   "GLMIS_VAL_UPD_FLAG" TEXT,
#   "IB" TEXT,
#   "IC_BAL_INCLUSION" TEXT,
#   "INSTRUMENT_CODE" TEXT,
#   "LCY_AMOUNT" REAL,
#   "MIS_FLAG" TEXT,
#   "MIS_HEAD" TEXT,
#   "MODULE" TEXT,
#   "ORIG_PNL_GL" REAL,
#   "PERIOD_CODE" TEXT,
#   "PRINT_STAT" TEXT,
#   "PRODUCT" TEXT,
#   "PRODUCT_ACCRUAL" TEXT,
#   "PRODUCT_PROCESSOR" TEXT,
#   "RELATED_AC_ENTRY_SR_NO" INTEGER,
#   "RELATED_ACCOUNT" TEXT,
#   "RELATED_CUSTOMER" REAL,
#   "RELATED_REFERENCE" TEXT,
#   "STMT_DT" TEXT,
#   "TRN_CODE" TEXT,
#   "TRN_DT" TEXT,
#   "TRN_REF_NO" TEXT,
#   "TXN_INIT_DATE" TEXT,
#   "USER_ID" TEXT,
#   "VALUE_DT" TEXT
# )
#
# --- Schema for table: CSTB_AMOUNT_TAG ---
# CREATE TABLE "CSTB_AMOUNT_TAG" (
# "ACCT_ENTRY_DEFN_ALLOWED" TEXT,
#   "AMOUNT_TAG" TEXT,
#   "AMOUNT_TAG_TYPE" TEXT,
#   "CHARGE_ALLOWED" TEXT,
#   "COMMISSION_ALLOWED" TEXT,
#   "DESCRIPTION" TEXT,
#   "INTEREST_ALLOWED" TEXT,
#   "ISSR_TAX_ALLOWED" TEXT,
#   "LANGUAGE_CODE" TEXT,
#   "LCY_AVG_EQL_REQD" TEXT,
#   "MODULE" TEXT,
#   "OFFSET_AMOUNT_TAG" TEXT,
#   "TAG_TO_BE_AVG_EQL_WITH" TEXT,
#   "TAX_ALLOWED" TEXT,
#   "TRACK_PAYABLE" TEXT,
#   "TRACK_RECEIVABLE" TEXT,
#   "TRACK_RECEIVABLES" TEXT,
#   "TRAN_TAX_ALLOWED" TEXT,
#   "UNREALISED" TEXT,
#   "USER_DEFINED" TEXT
# )
#
# --- Schema for table: CSTM_PRODUCT ---
# CREATE TABLE "CSTM_PRODUCT" (
# "ASSET_CATEGORIES_LIST" TEXT,
#   "AUTH_STAT" TEXT,
#   "BRANCHES_LIST" TEXT,
#   "CATEGORIES_LIST" TEXT,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CURRENCIES_LIST" TEXT,
#   "GEN_MT103P" TEXT,
#   "INCLUDE_FOR_TDS_CALC" TEXT,
#   "INSTRUMENT_PRODUCT_ALLOW" TEXT,
#   "LOCATION_LIST" TEXT,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MAXIMUM_RATE_VARIANCE" REAL,
#   "MOD_NO" INTEGER,
#   "MODULE" TEXT,
#   "NO_OF_LEGS" INTEGER,
#   "NORMAL_RATE_VARIANCE" REAL,
#   "ONCE_AUTH" TEXT,
#   "PART_OF_PRODUCT" TEXT,
#   "POOL_CODE" REAL,
#   "PORTFOLIO_PRODUCT_ALLOW" REAL,
#   "PRODUCT_CODE" TEXT,
#   "PRODUCT_DESCRIPTION" TEXT,
#   "PRODUCT_END_DATE" TEXT,
#   "PRODUCT_GROUP" TEXT,
#   "PRODUCT_REMARKS" TEXT,
#   "PRODUCT_SLOGAN" TEXT,
#   "PRODUCT_START_DATE" TEXT,
#   "PRODUCT_TYPE" TEXT,
#   "RATE_CODE_PREFERRED" TEXT,
#   "RATE_TYPE_PREFERRED" TEXT,
#   "RECORD_STAT" TEXT,
#   "RTH_CLASS" REAL,
#   "WAREHOUSE_CODE" REAL
# )
#
# --- Schema for table: GLTM_GLMASTER ---
# CREATE TABLE "GLTM_GLMASTER" (
# "AC_STMT_CYCLE" TEXT,
#   "AC_STMT_DAY" INTEGER,
#   "AC_STMT_REQUIRED" TEXT,
#   "AC_STMT_TYPE" TEXT,
#   "ADDRESS1" REAL,
#   "ADDRESS2" REAL,
#   "ADDRESS3" REAL,
#   "ADDRESS4" REAL,
#   "ALLOW_BACK_PERIOD_ENTRY" TEXT,
#   "AUTH_STAT" TEXT,
#   "AVG_BAL_REQD" TEXT,
#   "BAL_TRFR_ON_MIS_RECLASS" TEXT,
#   "BLOCK" TEXT,
#   "CATEGORY" INTEGER,
#   "CBANK_LINE_CR" TEXT,
#   "CBANK_LINE_DR" TEXT,
#   "CCY_POS_GL" TEXT,
#   "CCY_RES" TEXT,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CUSTOMER" TEXT,
#   "ED_FCYRVL_ENTRYPAIR" TEXT,
#   "ED_FCYRVL_SINGLEENTRY" TEXT,
#   "EOD_FCYRVL_REVR" TEXT,
#   "FIRST_AUTH" TEXT,
#   "FLG_POSITION_AC" TEXT,
#   "GEN_STMT_ONLY_ON_MVMT" TEXT,
#   "GL_CODE" TEXT,
#   "GL_DESC" TEXT,
#   "HO_LINE_CR" TEXT,
#   "HO_LINE_DR" TEXT,
#   "HO_RES" TEXT,
#   "INTRADAY_POSTING_GL" REAL,
#   "IS_ACCRUAL" TEXT,
#   "LEAF" TEXT,
#   "LOSS_ACC" TEXT,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MEDIA" REAL,
#   "MOD_NO" INTEGER,
#   "ONCE_AUTH" TEXT,
#   "PARENT_GL" TEXT,
#   "PL_SPLIT_REQD" TEXT,
#   "POSTING_RES" TEXT,
#   "PREV_YR_ADJ_GL" TEXT,
#   "PROFIT_ACC" TEXT,
#   "RECON" TEXT,
#   "RECORD_STAT" TEXT,
#   "REPOST_FCY_ENTRIES" TEXT,
#   "RES_CCY" TEXT,
#   "REVAL" TEXT,
#   "TYPE" INTEGER,
#   "ULTI_PARENT" TEXT
# )
#
# --- Schema for table: SMTB_MODULES ---
# CREATE TABLE "SMTB_MODULES" (
# "AC_CLASS_APPLICABLE" TEXT,
#   "ARC_APPLICABLE" TEXT,
#   "AUTH_STAT" TEXT,
#   "CB_CLASS_APPLICABLE" TEXT,
#   "CH_CLASS_APPLICABLE" TEXT,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CR_CLASS_APPLICABLE" TEXT,
#   "DISC_ACCR_APPLICABLE" TEXT,
#   "FA_BATCH_ENABLED" TEXT,
#   "FA_ENABLED" TEXT,
#   "IN_CLASS_APPLICABLE" TEXT,
#   "INSTALLED" TEXT,
#   "LICENSE" TEXT,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MOD_NO" INTEGER,
#   "MODULE_DESC" TEXT,
#   "MODULE_ID" TEXT,
#   "ONCE_AUTH" TEXT,
#   "PURGE_AVAILABLE" TEXT,
#   "RECORD_STAT" TEXT,
#   "RH_CLASS_APPLICABLE" TEXT,
#   "TA_CLASS_APPLICABLE" TEXT,
#   "USER_DEFINED_MODULE" TEXT
# )
#
# --- Schema for table: STTM_ACCOUNT_CLASS ---
# CREATE TABLE "STTM_ACCOUNT_CLASS" (
# "AC_CLASS_TYPE" TEXT,
#   "AC_STAT_DE_POST" TEXT,
#   "ACC_STATISTICS" TEXT,
#   "ACC_STMT_CYCLE" TEXT,
#   "ACC_STMT_CYCLE2" REAL,
#   "ACC_STMT_CYCLE3" REAL,
#   "ACC_STMT_TYPE" TEXT,
#   "ACC_STMT_TYPE2" TEXT,
#   "ACC_STMT_TYPE3" TEXT,
#   "ACCCLS_AUTODEP_LIST" TEXT,
#   "ACCOUNT_CLASS" TEXT,
#   "ACCOUNT_CODE" TEXT,
#   "ACST_FORMAT" TEXT,
#   "ADHOC_HOL" TEXT,
#   "ADVICE_DAYS" INTEGER,
#   "ALLOW_BACK_PERIOD_ENTRY" TEXT,
#   "ALLOW_PART_LIQ_WITH_AMT_BLK" TEXT,
#   "ALLOW_PREPAYMENT" REAL,
#   "ALLOW_TENOR_CHANGE" TEXT,
#   "ALLOW_TOPUP" TEXT,
#   "APPLICABLE_DEP_TENOR" TEXT,
#   "ATM_FACILITY" TEXT,
#   "AUTH_STAT" TEXT,
#   "AUTO_DEP_AC_CLASS" REAL,
#   "AUTO_DEP_BREAK_METHOD" TEXT,
#   "AUTO_DEP_CCY" TEXT,
#   "AUTO_DEP_DEF_RATE_CODE" TEXT,
#   "AUTO_DEP_DEF_RATE_TYPE" TEXT,
#   "AUTO_DEP_TRN_CODE" REAL,
#   "AUTO_EXTENSION" REAL,
#   "AUTO_PROV_REQD" TEXT,
#   "AUTO_REORDER_CHECK_LEAVES" INTEGER,
#   "AUTO_REORDER_CHECK_LEVEL" INTEGER,
#   "AUTO_REORDER_CHECK_REQUIRED" TEXT,
#   "AUTO_ROLLOVER" TEXT,
#   "AVAIL_BAL_REQD" TEXT,
#   "BALANCE_REPORT_SINCE" REAL,
#   "BALANCE_REPORT_TYPE" REAL,
#   "BLK_MAT_DAYS" INTEGER,
#   "BLK_MAT_MONTHS" INTEGER,
#   "BLK_OPEN_DAYS" INTEGER,
#   "BLK_OPEN_MONTHS" INTEGER,
#   "BRANCH_LIST" TEXT,
#   "BREAK_DEPOSITS_FIRST" TEXT,
#   "CAMT_FIXED_TIME" INTEGER,
#   "CAMT_FREQUENCY" INTEGER,
#   "CAMT_STMT_CYCLE" REAL,
#   "CASCADE_MONTH" TEXT,
#   "CASH_RESERVE_RATIO" REAL,
#   "CCY_LIST" TEXT,
#   "CCY_OPTION_PROD" REAL,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CHEQUE_BOOK_FACILITY" TEXT,
#   "CHG_START_ADV" TEXT,
#   "CHK_MIN_BAL_FOR_SWEEP" TEXT,
#   "CLOSE_ON_MATURITY" TEXT,
#   "CLUSTER_ID" REAL,
#   "COMP_WISE_TRACKING_REQD" TEXT,
#   "CONSOLIDATION_REQD" TEXT,
#   "CR_CB_LINE" REAL,
#   "CR_GL_LINE" REAL,
#   "CR_HO_LINE" REAL,
#   "CUSCAT_LIST" TEXT,
#   "DAYLIGHT_LIMIT" TEXT,
#   "DAYS" INTEGER,
#   "DAYS_AUTH_NOACTIVITY" INTEGER,
#   "DAYS_NOACTIVITY_NOTIFI" INTEGER,
#   "DAYS_UNAUTH_NOACTIVITY" INTEGER,
#   "DEFAULT_TENOR_DAYS" INTEGER,
#   "DEFAULT_TENOR_MONTHS" INTEGER,
#   "DEFAULT_TENOR_YEARS" INTEGER,
#   "DEFERRED_BAL_UPDATE" TEXT,
#   "DENM_DEPOSIT" TEXT,
#   "DEP_MULTIPLE_OF" INTEGER,
#   "DEPOSIT_PC_BRIDGE_GL" TEXT,
#   "DEPOSIT_PC_CATEGORY" REAL,
#   "DEPOSIT_PC_TRN_CODE" REAL,
#   "DESCRIPTION" TEXT,
#   "DIRECT_BANKING" TEXT,
#   "DISPLAY_IBAN_IN_ADVICES" TEXT,
#   "DORMANCY" INTEGER,
#   "DORMANT_PARAM" TEXT,
#   "DR_CB_LINE" REAL,
#   "DR_GL_LINE" REAL,
#   "DR_HO_LINE" REAL,
#   "DR_INT_LIQD_DAYS" INTEGER,
#   "DR_INT_LIQD_MODE" TEXT,
#   "DR_INT_NOTICE" TEXT,
#   "DR_INT_USING_RECV" TEXT,
#   "DUAL_CCY_DEPOSIT" TEXT,
#   "ENABLE_REV_SWEEP_IN" TEXT,
#   "ENABLE_SWEEP_IN" TEXT,
#   "END_DATE" REAL,
#   "ESCROW_PROCESS" TEXT,
#   "EVENT_CLASS_CODE" REAL,
#   "EXCL_SAMEDAY_RVRTRNS_FM_STMT" TEXT,
#   "EXCLUDE_FROM_DISTRIBUTION" REAL,
#   "EXPOSURE_CATEGORY" REAL,
#   "FIXING_DAYS" INTEGER,
#   "FREE_BANKING_DAYS" INTEGER,
#   "FREQUENCY" REAL,
#   "GEN_BALANCE_REPORT" TEXT,
#   "GEN_INTERIM_STMT" TEXT,
#   "GEN_INTERIM_STMT_ON_MVMT" TEXT,
#   "GRACE_PERIOD" INTEGER,
#   "HAS_DRCR_ADV" TEXT,
#   "HAS_IS" TEXT,
#   "HOLIDAY_CALENDAR" TEXT,
#   "HOLIDAY_MOVEMENT" TEXT,
#   "IBAN_ACC_TYPE" REAL,
#   "IBAN_REQUIRED" TEXT,
#   "IC_INCLUSION" TEXT,
#   "ILM_APPLICABLE" TEXT,
#   "INT_RATE_OPTION_REDAMT" TEXT,
#   "INT_RATE_OPTION_REMAMT" TEXT,
#   "INT_RATE_OPTION_TOPUP" TEXT,
#   "INTERIM_REPORT_SINCE" REAL,
#   "INTERIM_REPORT_TYPE" REAL,
#   "INTERPAY" TEXT,
#   "INTRATE_CUMAMT_REQD" TEXT,
#   "LIMIT_CHECK_REQUIRED" TEXT,
#   "LINK_CCY" REAL,
#   "LODGEMENT_BOOK" TEXT,
#   "LRGDRBALFLG" TEXT,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MAT_ADV_NOTPRD" INTEGER,
#   "MAT_DT_MOV_ACROS_MONTH" TEXT,
#   "MAX_AMOUNT" INTEGER,
#   "MAX_NO_CHEQUE_REJECTIONS" INTEGER,
#   "MAX_TENOR_DAYS" INTEGER,
#   "MAX_TENOR_MONTHS" INTEGER,
#   "MAX_TENOR_YEARS" INTEGER,
#   "MIN_AMOUNT" INTEGER,
#   "MIN_BAL_REQD" INTEGER,
#   "MIN_ECA_BLOCK_AMOUNT" INTEGER,
#   "MIN_TENOR_DAYS" INTEGER,
#   "MIN_TENOR_MONTHS" INTEGER,
#   "MIN_TENOR_YEARS" INTEGER,
#   "MINOR_MAJOR" REAL,
#   "MOD_NO" INTEGER,
#   "MONTH_END_DEPOSIT" TEXT,
#   "MOVE_INT_TO_UNCLAIMED" TEXT,
#   "MOVE_PRIC_TO_UNCLAIMED" TEXT,
#   "MUDARABAH_ACC_CLASS" REAL,
#   "MUDARABAH_FUND_ID" REAL,
#   "MULTI_CURRENCY" TEXT,
#   "NATURAL_GL_SIGN" TEXT,
#   "NOTIFI_FREQUENCY" TEXT,
#   "OFFLINE_LIMIT" REAL,
#   "ONCE_AUTH" TEXT,
#   "OVERDRAFT_FACILITY" TEXT,
#   "PARTIAL_LIQUIDATION" TEXT,
#   "PASSBOOK_FACILITY" TEXT,
#   "PASSBOOK_RT_PRODUCT" REAL,
#   "PBK_COMP_REQ" TEXT,
#   "PBK_LIMIT_UNPRINT_TRN" INTEGER,
#   "PBK_TRN_CODE" REAL,
#   "POOL_CODE" REAL,
#   "PRE_CLSR_BASED_ON" TEXT,
#   "PRE_CLSR_FACTOR" REAL,
#   "PRE_REDEMPTION" REAL,
#   "PRODUCT_LIST" TEXT,
#   "PROFIT_CALC_BAL_TYPE" REAL,
#   "PROFIT_SHARING" REAL,
#   "PROJECT_ACCOUNT" TEXT,
#   "PROV_CCY_TYPE" TEXT,
#   "PROVIDE_INTEREST_ON_BROKEN_DEP" TEXT,
#   "PROVISIONING_FREQUENCY" REAL,
#   "RATE_CHART_TENOR" TEXT,
#   "RD_FLAG" TEXT,
#   "RD_MAX_SCHEDULE_DAYS" INTEGER,
#   "RD_MIN_INSTALLMENT_AMT" REAL,
#   "RD_MIN_SCHEDULE_DAYS" INTEGER,
#   "RD_MOVE_FUNDS_ON_OVD" TEXT,
#   "RD_MOVE_MAT_TO_UNCLAIMED" TEXT,
#   "RD_SCHEDULE_DAYS" INTEGER,
#   "RD_SCHEDULE_MONTHS" INTEGER,
#   "RD_SCHEDULE_YEARS" INTEGER,
#   "RECOMPUTE_MAT_DATE" TEXT,
#   "RECORD_STAT" TEXT,
#   "REDEMPTION" REAL,
#   "REFERENCE_DATE" REAL,
#   "REFERRAL_REQUIRED" TEXT,
#   "REG_D_APPLICABLE" TEXT,
#   "REGD_PERIODICITY" TEXT,
#   "REPL_CUST_SIG" TEXT,
#   "SAL_BLK_DAYS" INTEGER,
#   "SEND_NOTIFICATION" TEXT,
#   "SPECIAL_RATE_CODE" REAL,
#   "SPEND_ANALYSIS_REQD" TEXT,
#   "STACCCLS_BRANCH_LIST" REAL,
#   "STACCCLS_CCY_LIST" REAL,
#   "STACCCLS_CUSCAT_LIST" REAL,
#   "START_DATE" TEXT,
#   "STATEMENT_DAY" INTEGER,
#   "STATEMENT_DAY2" INTEGER,
#   "STATEMENT_DAY3" INTEGER,
#   "STATUS_CHANGE_AUTOMATIC" TEXT,
#   "SWEEP_MODE" TEXT,
#   "TD_RATECHART_ALLOW" TEXT,
#   "TRACK_ACCRUED_IC" TEXT,
#   "TRACK_RECEIVABLE" TEXT,
#   "TRN_CODE" REAL,
#   "TRN_REV_CODE" REAL,
#   "TRNOVER_LMT_CODE" REAL,
#   "TRUSTAC_CASH_LIMIT" REAL,
#   "TURNOVER_EVENT_CLASS_CODE" REAL,
#   "TURNOVER_RTOH_CODE" REAL,
#   "TXN_CODE_LIST" TEXT,
#   "VERIFY_FUNDS_FOR_DRINT" TEXT
# )
#
# --- Schema for table: STTM_BRANCH ---
# CREATE TABLE "STTM_BRANCH" (
# "ALLOW_CORPORATE_ACCESS" TEXT,
#   "ALT_BRANCH_CODE" REAL,
#   "ATM_SUSPENSE_GL" TEXT,
#   "AUTH_STAT" TEXT,
#   "AUTO_AUTH" TEXT,
#   "BACK_VALUE_DAYS" INTEGER,
#   "BACK_VALUED_CHK_REQ" TEXT,
#   "BANK_CODE" TEXT,
#   "BBAN_BANK_CODE" REAL,
#   "BBAN_BRN_CODE" REAL,
#   "BBAN_DATA_TYPE" REAL,
#   "BBAN_FORMAT_MSK" REAL,
#   "BRANCH_ADDR1" TEXT,
#   "BRANCH_ADDR2" TEXT,
#   "BRANCH_ADDR3" TEXT,
#   "BRANCH_CODE" INTEGER,
#   "BRANCH_GROUP" REAL,
#   "BRANCH_LCY" TEXT,
#   "BRANCH_NAME" TEXT,
#   "BRN_AVAIL_STAT" TEXT,
#   "CASA_AMTBLK_TRNCODE" REAL,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CHEQUE_STALE_DAYS" INTEGER,
#   "CHK_DIG_ALGO" TEXT,
#   "CHQNO_MASK" TEXT,
#   "CIF_ID" REAL,
#   "CLEARING_ACC" REAL,
#   "CLEARING_BANK_CODE" TEXT,
#   "CLEARING_BRN" INTEGER,
#   "CLG_BRN_CODE" INTEGER,
#   "COD_ATM_BRANCH" INTEGER,
#   "COD_ATM_STOP" REAL,
#   "COD_CUST_TRANSFER" TEXT,
#   "COD_IB_TRN_CODE" INTEGER,
#   "COD_INST_ID" INTEGER,
#   "COD_START_TANK" TEXT,
#   "CONSOL_TAX_CERT_REQD" TEXT,
#   "CONT_SUSPENSE_GL_FCY" REAL,
#   "CONTINGENT_SUSPENSE_GLSL" TEXT,
#   "CONVERSION_GL" REAL,
#   "CONVERSION_TXNCODE" REAL,
#   "COUNTRY_CODE" TEXT,
#   "CRSUS_PROD" REAL,
#   "CURRENT_CYCLE" TEXT,
#   "CURRENT_PERIOD" TEXT,
#   "CURRENT_TAX_CYCLE" REAL,
#   "DEF_BANK_OPER_CODE" TEXT,
#   "DEFERRED_STMT" TEXT,
#   "DEFERRED_STMT_STATUS" TEXT,
#   "DRSUS_PROD" REAL,
#   "DSN_NAME" TEXT,
#   "ELCM_REPLICATION" TEXT,
#   "END_OF_INPUT" TEXT,
#   "ENTERPRISE_GL" TEXT,
#   "EOC_STAGE" TEXT,
#   "FILE_CONS_TRN_CODE" REAL,
#   "FUND_BRANCH" TEXT,
#   "GEN_MT103" TEXT,
#   "GEN_MT103P" TEXT,
#   "GENERATE" INTEGER,
#   "GL_CLASS" TEXT,
#   "GMT_AHEAD" TEXT,
#   "GMT_HOURS" INTEGER,
#   "GMT_MINS" INTEGER,
#   "HOST_NAME" TEXT,
#   "IBAN_CHK_DIG_ALGO" TEXT,
#   "IBAN_CNTRY_CD" TEXT,
#   "IBAN_MASK_ACCOUNT_NUMBER" REAL,
#   "IBAN_MASK_BANK_CODE" REAL,
#   "ICEOD_STATUS" TEXT,
#   "INDIVIDUAL_TAX_CERT_REQD" TEXT,
#   "INTERDICT_CHECK_REQD" TEXT,
#   "INTERDICT_TIME_OUT" INTEGER,
#   "INTERNAL_SWAP_CUSTOMER" REAL,
#   "JOB_STAT" TEXT,
#   "LDAP_TEMPLATE" TEXT,
#   "LMTEXP_NOTIFY_DAYS" INTEGER,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MAX_CONT_SUSPENSE_AMT" REAL,
#   "MAX_REAL_SUSPENSE_AMT" REAL,
#   "MINOR_AGE" INTEGER,
#   "MIS_CCY_MISMATCH_GROUP" REAL,
#   "MOD_NO" INTEGER,
#   "MSG_GEN_DAYS" INTEGER,
#   "NETTING_SUSPENSE_GL" TEXT,
#   "NOTICE_PERIOD" INTEGER,
#   "OFFSET_CLEARING_ACCOUNT" REAL,
#   "OFFSET_HOURS" INTEGER,
#   "OFFSET_HR" INTEGER,
#   "OFFSET_MIN" INTEGER,
#   "OFFSET_MINS" INTEGER,
#   "ONCE_AUTH" TEXT,
#   "PARENT_BRANCH" INTEGER,
#   "PC_CLEARING_BRN" INTEGER,
#   "PL_SPLIT_REQD" TEXT,
#   "POSITION_ASSET_GL" REAL,
#   "POSITION_LIABILITY_GL" REAL,
#   "PROCEED_WITHOUT_FLOAT" TEXT,
#   "PROVISIONING_FREQUENCY" TEXT,
#   "RECORD_STAT" TEXT,
#   "REFERRAL_HR" INTEGER,
#   "REFERRAL_MIN" INTEGER,
#   "REGIONAL_OFFICE" INTEGER,
#   "REP_HISTORY_PERIOD" INTEGER,
#   "REPORT_DSN" TEXT,
#   "REV_SUSPENSE_ENTRY_DAYS" INTEGER,
#   "REVAL_BRANCH" REAL,
#   "ROUTING_NO" INTEGER,
#   "SECTOR_CODE" INTEGER,
#   "STATUS_PROCESSING_BASIS" TEXT,
#   "SUSPENSE_BATCH_NO" REAL,
#   "SUSPENSE_ENTRY_REQD" TEXT,
#   "SUSPENSE_GL_FCY" TEXT,
#   "SUSPENSE_GLSL" TEXT,
#   "SUSPENSE_TXN_CODE" REAL,
#   "SWIFT_ADDR" TEXT,
#   "TAX_CERT_DAY" REAL,
#   "TAX_CERT_FREQ" REAL,
#   "TAX_CYCLE_CLOSURE_CHK_REQD" TEXT,
#   "TELEX_ADDR" REAL,
#   "TIME_LEVEL" INTEGER,
#   "TRACK_PY_PNL_ADJUSTMENT" TEXT,
#   "TRANSACTION_CODE" REAL,
#   "TRANSFER_TYPE" TEXT,
#   "UNCOLLECTED_FUNDS_BASIS" TEXT,
#   "USER_DEF_ALGO" REAL,
#   "WALKIN_CUSTOMER" INTEGER,
#   "WEEK_HOL1" INTEGER,
#   "WEEK_HOL2" REAL
# )
#
# --- Schema for table: STTM_TRN_CODE ---
# CREATE TABLE "STTM_TRN_CODE" (
# "ACUMEN_TRN_CODE" TEXT,
#   "AML_MONITORING" TEXT,
#   "AUTH_STAT" TEXT,
#   "AVAIL_BAL_REQD" TEXT,
#   "AVL_DAYS" INTEGER,
#   "AVL_INFO" TEXT,
#   "BAL_UPDATE_THRU_PPC" TEXT,
#   "CHECKER_DT_STAMP" TEXT,
#   "CHECKER_ID" TEXT,
#   "CHEQUE_MANDATORY" TEXT,
#   "COMPONENT_TYPE" TEXT,
#   "CONSIDER_COVER_ACC" TEXT,
#   "CONSIDER_FOR_ACTIVITY" TEXT,
#   "CREDIT_OVERRIDE_TRACKING" TEXT,
#   "DEBIT_OVERRIDE_TRACKING" TEXT,
#   "ESCROW_PROCESSING" TEXT,
#   "EXEMPT_ADV_INTEREST" TEXT,
#   "IB_IN_LCY" TEXT,
#   "IC_BAL_INCLUSION" TEXT,
#   "IC_PENALTY" TEXT,
#   "IC_TOVER_INCLUSION" TEXT,
#   "IC_TXN_COUNT" TEXT,
#   "IC_TXN_COUNT_NUMBER" INTEGER,
#   "IGNORE_LM_BVT_PROCESSING" REAL,
#   "INTRADAY_RELEASE" TEXT,
#   "LEAVE_SALARY_PROCESSING" REAL,
#   "MAKER_DT_STAMP" TEXT,
#   "MAKER_ID" TEXT,
#   "MIS_HEAD" TEXT,
#   "MOD_NO" INTEGER,
#   "NEW_VAL_DATE" REAL,
#   "ONCE_AUTH" TEXT,
#   "PRODUCT_CAT" REAL,
#   "RECORD_STAT" TEXT,
#   "SALARY_CREDIT" TEXT,
#   "STMT_DT_BASIS" TEXT,
#   "TRN_CODE" TEXT,
#   "TRN_DESC" TEXT,
#   "TRN_SWIFT_CODE" TEXT,
#   "TRNOVER_LMT_INCLUSION" TEXT
# )

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

for table in tables:
    print(table[0])
# Out:
# ACVWS_ALL_AC_ENTRIES_ACRJRNAL
# CSTB_AMOUNT_TAG
# CSTM_PRODUCT
# GLTM_GLMASTER
# SMTB_MODULES
# STTM_ACCOUNT_CLASS
# STTM_BRANCH
# STTM_TRN_CODE
